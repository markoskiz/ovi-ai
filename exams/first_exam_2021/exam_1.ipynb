# %% [markdown]
# # Испит по Основи на Вештачката Интелигенција
#
# **Датум**: 18.02.2021

# %% [markdown]
# ## Задача 1

# %% [markdown]
# **(25 поени)**
# Даден е графот од сликата. Сите врски помеѓу јазлите се двонасочни и се означени со нивната цена. Секој јазол е означен со латинична буква и содржи број во загради кој одговара на евристичката проценка на цената од тој јазол до целта. Во конкретниот случај, почетниот јазол е А, а крајниот јазол односно целта е Z. Со примена на соодветен алгоритам за пребарување треба да се најде пат од јазолот А до јазолот Z. Јазлите се разгрануваат по азбучен ред, доколку агоритамот за пребарување не наложува поинаку.

# %%
from IPython import display
display.Image('images/1.png', width=600)

# %% [markdown]
# **а)** Најнапред извршете пребарување прво по широчина. Не ги разгранувајте патиштата на јазли кои веќе се содржани во тој пат. Користете ја конвенцијата дека решението е најдено кога патот со целниот јазол ќе се најде на почетокот од листата разгранети патишта. На крајот од пребарувањето:
# - Подредете ги во редица јазлите според редоследот на разгранување.

# %% [markdown]
# - Запишете го пронајдениот пат со пребарувањето прво по широчина.

# %% [markdown]
# - Што ќе се случи ако е дозволено разгранувањето патишта и јазли кои се веќе содржани во патот – дали алгоритамот ќе најде пат од А до Z?

# %% [markdown]
# - Дали ова пребарување е комплетно?

# %% [markdown]
# **б)** Сега извршете пребарување прво по длабочина. Не ги разгранувајте патиштата на јазли кои веќе се содржани во тој пат. Користете ја конвенцијата дека решението е најдено кога патот со целниот јазол ќе се најде на почетокот од листата разгранети патишта. На крајот од пребарувањето:

# %% [markdown]
# - Подредете ги во редица јазлите според редоследот на разгранување.

# %% [markdown]
# - Запишете го пронајдениот пат со пребарувањето прво по длабочина.

# %% [markdown]
# - Што ќе се случи ако е дозволено разгранувањето на патиштата и на јазли кои се веќе содржани во патот – дали алгоритамот ќе најде пат од А до Z?

# %% [markdown]
# - Дали ова пребарување е комплетно?

# %% [markdown]
# **в)** На крајот применете го алгоритамот за А* пребарување.
# - Подредете ги во редица јазлите според редоследот на разгранување.

# %% [markdown]
# - Запишете го пронајдениот пат со А* пребарувањето.

# %% [markdown]
# - Дали пронајдениот пат е оптимален? Зошто не?
