# %% [markdown]
# # Прв парцијален испит по Основи на Вештачката Интелигенција

# %% [markdown]
# ## Задача 1

# %%
from IPython import display

# %% [markdown]
# **(50 поени)** Даден е графот од сликата.

# %%
display.Image('images/graph.png', width=300)

# %% [markdown]
# Како резултат на пребарувањето на овој граф со различни постапки, добиени се стебла на пребарување кои се претставени подолу (означени од G1 од G7). Секое од стеблата е генерирано со еден од следните алгоритми за пребарување:
#
# - Пребарување прво по длабочина
# - Пребарување прво по широчина
# - Пребарување со униформна цена
# - Алчно пребарување прво од најдобриот јазол
# - А* пребарување

# %% [markdown]
# Сите стебла се добиени со пребарување почнувајќи од јазолот А, а целта е јазолот G.
#
# Да се претпостави дека наследниците на секој јазол се посетени по азбучен редослед. Секое стебло ги
# прикажува сите посетени јазли. Бројот покрај секој јазол ја прикажува “цената“ на тој јазол за конкретниот
# алгоритам на пребарување. Сите применети алгоритми користат листа на разгранети јазли. Кај
# евристичките алгоритми на пребарување е употребена една од следните евристики:

# %%
display.Image('images/heuristics.png', width=600)

# %% [markdown]
# **(а)** За секое стебло да се укаже на применетиот алгоритам на пребарување.
#
# **(б)** За алгоритмите кои користат евристика, да се каже која евристика е употребена.
#
# **(в)** За секој алгоритам на пребарување да се каже дали го наоѓа оптималното решение.

# %%
for i in range(1, 8):
    display.display(display.Image(f'images/G{i}.png', width=300))

# %% [markdown]
# ## Решение
