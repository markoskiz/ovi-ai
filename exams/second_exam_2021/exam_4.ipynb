# %% [markdown]
# # Испит по Основи на Вештачката Интелигенција
#
# **Датум**: 09.06.2021

# %% [markdown]
# ## Задача 4

# %% [markdown]
# **(30 поени)**
# Дадена е невронската мрежа од сликата. Таа треба да се обучи точно да ја претстави функцијата $f: X \rightarrow Y$, каде што влезниот вектор $X = \begin{pmatrix} X 1 & X 2 \end{pmatrix}$ има две карактеристики. Тежините $w_1, w_2, w_3, w_4, w_5$ и $w_6$ можат да бидат произволни. На располагање се две активациски функции за невроните од мрежата:
#
# а) $S(\alpha) =$ sign $\begin{bmatrix} \frac{1}{1+e^{-\alpha}} - 0.5 \end{bmatrix}$
#
# б) $L(\alpha) = c\alpha $
#
# каде што во двата случаи:
#
# $\alpha = \sum_i w_i X_i$

# %%
from IPython import display
display.Image('images/4.png', width=600)

# %% [markdown]
# а) Доделете ја точната активациска функција на невроните во мрежата ( $S$ или $L$ ), така што набљудуваната невронска мрежа ќе симулира линеарна регресија:
#
# $Y = \beta_1 X_1 + \beta_2 X_2$

# %% [markdown]
# б) Изразете ги $\beta_1$ и $\beta_2$ во функција од тежините на мрежата.

# %% [markdown]
# в) Доделете ја точната активациска функција на невроните во мрежата ( $S$ или $L$ ), така што набљудуваната невронска мрежа ќе ја симулира функцијата:
#
# $Y =$ sign $\begin{pmatrix} \beta_1 X_1 + \beta_2 X_2 \end{pmatrix} $

# %% [markdown]
# б) Изразете ги новите $\beta_1$ и $\beta_2$ во функција од тежините на мрежата.
